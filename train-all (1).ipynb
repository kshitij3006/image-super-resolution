# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# 🧩 Cell 1 — Setup & Imports (Kaggle)
import os, glob, cv2, random, math, numpy as np, shutil, json
from datetime import datetime
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Input, Add
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

print("TensorFlow:", tf.__version__)
# Out:
# TensorFlow: 2.18.0

# %%
# 🧩 Cell 2 — Config (edit these as you like)
# If you know the exact path, set it directly (else auto-detects in next cell):
DATASET_ROOT = None  # e.g. "/kaggle/input/adityachandrasekhar-image-super-resolution"

TARGET_SIZE   = (128, 128)  # training patch size
DOWNSCALE     = 2           # synthetic LR scale if LR not provided
RANDOM_CROPS  = 0           # e.g., 4 or 8 for extra random crops per image
SEED          = 42

MODELS_TO_RUN = ["edsr", "vdsr"]   # train all three
LR            = 1e-4
EPOCHS        = 300                           # raise if you have more time
BATCH_SIZE    = 8

OUTPUT_DIR    = "/kaggle/working"

random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)

# %%
# 🧩 Cell 3 — Locate Dataset (auto-detect for https://www.kaggle.com/datasets/adityachandrasekhar/image-super-resolution)
def find_dataset_root():
    if DATASET_ROOT and os.path.isdir(DATASET_ROOT):
        return DATASET_ROOT
    candidates = sorted(glob.glob("/kaggle/input/*image*super*resolution*")) \
               + sorted(glob.glob("/kaggle/input/*super*resolution*")) \
               + sorted(glob.glob("/kaggle/input/*"))
    IMG_EXTS = (".jpg",".jpeg",".png",".bmp")
    for root in candidates:
        if os.path.isdir(root):
            for d,_,f in os.walk(root):
                if any(x.lower().endswith(IMG_EXTS) for x in f):
                    return root
    return None

DATA_ROOT = find_dataset_root()
assert DATA_ROOT is not None, "No dataset found under /kaggle/input. Add the dataset to your notebook."
print("DATA_ROOT:", DATA_ROOT)
# Out:
# DATA_ROOT: /kaggle/input/image-super-resolution

# %%
# 🧩 Cell 4 — Detect LR/HR folders if present (else we will synthesize LR)
def find_lr_hr_dirs(root):
    lr_names = ["LR","lr","Low","low","low_res","lowresolution"]
    hr_names = ["HR","hr","High","high","high_res","highresolution"]
    for base, dirs, _ in os.walk(root):
        s = set(dirs)
        for l in lr_names:
            for h in hr_names:
                if l in s and h in s:
                    lr_dir, hr_dir = os.path.join(base,l), os.path.join(base,h)
                    if len(glob.glob(os.path.join(lr_dir,"*"))) and len(glob.glob(os.path.join(hr_dir,"*"))):
                        return lr_dir, hr_dir
    return None, None

LR_DIR, HR_DIR = find_lr_hr_dirs(DATA_ROOT)
print("LR_DIR:", LR_DIR)
print("HR_DIR:", HR_DIR)

IMG_EXTS = (".jpg",".jpeg",".png",".bmp")
def list_images_recursive(root):
    out = []
    for d,_,f in os.walk(root):
        for fn in f:
            if fn.lower().endswith(IMG_EXTS):
                out.append(os.path.join(d,fn))
    return sorted(out)

if HR_DIR and LR_DIR:
    hr_paths = list_images_recursive(HR_DIR)
    lr_paths = list_images_recursive(LR_DIR)

    def stem(p):
        s = os.path.splitext(os.path.basename(p))[0].lower()
        for tag in ["_x2","_x3","_x4","-x2","-x3","-x4","@2x","@3x","@4x"]:
            s = s.replace(tag,"")
        return s

    lr_map = {stem(p): p for p in lr_paths}
    pairs = [(lr_map[stem(h)], h) for h in hr_paths if stem(h) in lr_map]
    if not pairs:
        print("Could not pair LR/HR by filenames; will synthesize LR from HR.")
        pairs = None
else:
    hr_paths = list_images_recursive(DATA_ROOT)
    pairs = None

print("Total HR images:", len(hr_paths))
if pairs is not None:
    print("Total LR/HR pairs:", len(pairs))
# Out:
# LR_DIR: /kaggle/input/image-super-resolution/dataset/Raw Data/low_res
# HR_DIR: /kaggle/input/image-super-resolution/dataset/Raw Data/high_res
# Total HR images: 855
# Total LR/HR pairs: 855

# %%
# 🧩 Cell 5 — Preprocessing utilities
def read_rgb(path):
    im = cv2.imread(path, cv2.IMREAD_COLOR)
    if im is None: return None
    return cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

def ensure_min_size(img, size):
    th, tw = size
    h, w = img.shape[:2]
    if h < th or w < tw:
        scale = max(th/h, tw/w)
        img = cv2.resize(img, (int(w*scale)+1, int(h*scale)+1), interpolation=cv2.INTER_CUBIC)
    return img

def center_crop(img, size):
    img = ensure_min_size(img, size)
    h, w = img.shape[:2]
    th, tw = size
    y = (h - th)//2
    x = (w - tw)//2
    return img[y:y+th, x:x+tw]

def random_crop(img, size):
    img = ensure_min_size(img, size)
    h, w = img.shape[:2]
    th, tw = size
    y = random.randint(0, h - th)
    x = random.randint(0, w - tw)
    return img[y:y+th, x:x+tw]

def synthesize_lr(hr_img, downscale=DOWNSCALE):
    h, w = hr_img.shape[:2]
    small = cv2.resize(hr_img, (max(1,w//downscale), max(1,h//downscale)), interpolation=cv2.INTER_AREA)
    lr    = cv2.resize(small, (w, h), interpolation=cv2.INTER_CUBIC)
    return lr

# %%
# 🧩 Cell 6 — Build dataset (X=LR, Y=HR) from real LR/HR or synthetic LR
def build_dataset_from_pairs(pairs):
    X, Y = [], []
    for lp, hp in pairs:
        lr = read_rgb(lp); hr = read_rgb(hp)
        if lr is None or hr is None: continue

        crop_fns = [center_crop] + ([random_crop]*RANDOM_CROPS if RANDOM_CROPS>0 else [])
        for fn in crop_fns:
            lr_c = cv2.resize(fn(lr, TARGET_SIZE), TARGET_SIZE, interpolation=cv2.INTER_CUBIC)
            hr_c = fn(hr, TARGET_SIZE)
            X.append(lr_c.astype(np.float32)/255.0)
            Y.append(hr_c.astype(np.float32)/255.0)
    return np.asarray(X, np.float32), np.asarray(Y, np.float32)

def build_dataset_from_hr(hr_paths):
    X, Y = [], []
    for hp in hr_paths:
        hr = read_rgb(hp)
        if hr is None: continue

        crop_fns = [center_crop] + ([random_crop]*RANDOM_CROPS if RANDOM_CROPS>0 else [])
        for fn in crop_fns:
            hr_c = fn(hr, TARGET_SIZE)
            lr_c = synthesize_lr(hr_c, DOWNSCALE)
            X.append(lr_c.astype(np.float32)/255.0)
            Y.append(hr_c.astype(np.float32)/255.0)
    return np.asarray(X, np.float32), np.asarray(Y, np.float32)

if pairs is not None:
    X, Y = build_dataset_from_pairs(pairs)
else:
    X, Y = build_dataset_from_hr(hr_paths)

print("LR shape:", X.shape, "HR shape:", Y.shape)

lr_train, lr_val, hr_train, hr_val = train_test_split(X, Y, test_size=0.2, random_state=SEED)
print("Train:", lr_train.shape, hr_train.shape, " Val:", lr_val.shape, hr_val.shape)
# Out:
# LR shape: (855, 128, 128, 3) HR shape: (855, 128, 128, 3)
# Train: (684, 128, 128, 3) (684, 128, 128, 3)  Val: (171, 128, 128, 3) (171, 128, 128, 3)

# %%
# 🧩 Cell 7 — Models (SRCNN / EDSR-lite / VDSR-lite) and utilities
def build_srcnn(input_shape=(128,128,3)):
    inp = Input(shape=input_shape)
    x = Conv2D(64, 9, padding="same", activation="relu")(inp)
    x = Conv2D(32, 5, padding="same", activation="relu")(x)
    x = Conv2D(3,  5, padding="same")(x)
    return Model(inp, x, name="SRCNN")

def edsr_res_block(x, f):
    skip = x
    x = Conv2D(f, 3, padding="same", activation="relu")(x)
    x = Conv2D(f, 3, padding="same")(x)
    return Add()([skip, x])

def build_edsr(input_shape=(128,128,3), num_blocks=16, f=64):
    inp = Input(shape=input_shape)
    x = Conv2D(f, 3, padding="same")(inp)
    for _ in range(num_blocks):
        x = edsr_res_block(x, f)
    x = Conv2D(3, 3, padding="same")(x)
    return Model(inp, x, name="EDSR-lite")

def build_vdsr(input_shape=(128,128,3), depth=20, f=64):
    inp = Input(shape=input_shape)
    x = Conv2D(f, 3, padding="same", activation="relu")(inp)
    for _ in range(depth-2):
        x = Conv2D(f, 3, padding="same", activation="relu")(x)
    x = Conv2D(3, 3, padding="same")(x)
    return Model(inp, x, name="VDSR-lite")

def get_model(name, input_shape=(128,128,3)):
    n = name.lower()
    if n == "srcnn": return build_srcnn(input_shape)
    if n == "edsr":  return build_edsr(input_shape)
    if n == "vdsr":  return build_vdsr(input_shape)
    raise ValueError("Choose from {'srcnn','edsr','vdsr'}")

def psnr_metric(y_true, y_pred):
    return tf.image.psnr(y_true, y_pred, max_val=1.0)

# %%
# 🧩 Cell 8 — Train ALL 3 models (SRCNN, EDSR, VDSR) sequentially; save best+final for each
all_model_records = []   # keep paths for zipping later

for model_name in MODELS_TO_RUN:
    print(f"\n==============================")
    print(f"🔹 Training {model_name.upper()} ...")
    print(f"==============================")

    model = get_model(model_name, input_shape=(TARGET_SIZE[0], TARGET_SIZE[1], 3))
    model.compile(optimizer=Adam(LR), loss="mse", metrics=[psnr_metric])
    model.summary()

    best_path  = os.path.join(OUTPUT_DIR, f"{model_name}_best.h5")
    final_path = os.path.join(OUTPUT_DIR, f"{model_name}_final.h5")

    callbacks = [
        ModelCheckpoint(best_path, monitor="val_psnr_metric", mode="max", save_best_only=True, verbose=1),
        ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=8, min_lr=1e-6, verbose=1),
        EarlyStopping(monitor="val_loss", patience=15, restore_best_weights=True, verbose=1),
    ]

    history = model.fit(
        lr_train, hr_train,
        validation_data=(lr_val, hr_val),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE,
        callbacks=callbacks,
        verbose=1
    )

    model.save(final_path)
    print(f"✅ Saved {model_name.upper()} -> best: {best_path}, final: {final_path}")

    # save a couple previews per model
    preds_dir = os.path.join(OUTPUT_DIR, f"preds_{model_name}")
    os.makedirs(preds_dir, exist_ok=True)

    def save_preview(lr, hr, pred, idx):
        def to_u8(x): return np.clip((x*255.0).round(),0,255).astype(np.uint8)
        lr_u, hr_u, pd_u = to_u8(lr), to_u8(hr), to_u8(pred)
        cv2.imwrite(os.path.join(preds_dir,f"{idx:03d}_lr.png"),  cv2.cvtColor(lr_u, cv2.COLOR_RGB2BGR))
        cv2.imwrite(os.path.join(preds_dir,f"{idx:03d}_hr.png"),  cv2.cvtColor(hr_u, cv2.COLOR_RGB2BGR))
        cv2.imwrite(os.path.join(preds_dir,f"{idx:03d}_sr.png"),  cv2.cvtColor(pd_u, cv2.COLOR_RGB2BGR))

    for i in range(min(3, lr_val.shape[0])):  # 3 previews per model
        pred = model.predict(lr_val[i:i+1], verbose=0)[0]
        save_preview(lr_val[i], hr_val[i], pred, i)

    all_model_records.append({
        "name": model_name,
        "best": best_path,
        "final": final_path,
        "preds_dir": preds_dir
    })

print("\nAll models trained and saved.")
# Out:
# ==============================
# 🔹 Training EDSR ...
# ==============================
# Model: "EDSR-lite"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 128, 128,  │      1,792 │ input_layer_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 128, 128,  │     36,928 │ conv2d_6[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 128, 128,  │     36,928 │ conv2d_7[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 128, 128,  │          0 │ conv2d_6[0][0],   │
# │                     │ 64)               │            │ conv2d_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 128, 128,  │     36,928 │ add[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_9[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 128, 128,  │          0 │ add[0][0],        │
# │                     │ 64)               │            │ conv2d_10[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 128, 128,  │     36,928 │ add_1[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_11[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 128, 128,  │          0 │ add_1[0][0],      │
# │                     │ 64)               │            │ conv2d_12[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 128, 128,  │     36,928 │ add_2[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_13[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 128, 128,  │          0 │ add_2[0][0],      │
# │                     │ 64)               │            │ conv2d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 128, 128,  │     36,928 │ add_3[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_15[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 128, 128,  │          0 │ add_3[0][0],      │
# │                     │ 64)               │            │ conv2d_16[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 128, 128,  │     36,928 │ add_4[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_17[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 128, 128,  │          0 │ add_4[0][0],      │
# │                     │ 64)               │            │ conv2d_18[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 128, 128,  │     36,928 │ add_5[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_19[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 128, 128,  │          0 │ add_5[0][0],      │
# │                     │ 64)               │            │ conv2d_20[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 128, 128,  │     36,928 │ add_6[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_21[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 128, 128,  │          0 │ add_6[0][0],      │
# │                     │ 64)               │            │ conv2d_22[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 128, 128,  │     36,928 │ add_7[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_23[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 128, 128,  │          0 │ add_7[0][0],      │
# │                     │ 64)               │            │ conv2d_24[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 128, 128,  │     36,928 │ add_8[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_25[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 128, 128,  │          0 │ add_8[0][0],      │
# │                     │ 64)               │            │ conv2d_26[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 128, 128,  │     36,928 │ add_9[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_27[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 128, 128,  │          0 │ add_9[0][0],      │
# │                     │ 64)               │            │ conv2d_28[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 128, 128,  │     36,928 │ add_10[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_29[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 128, 128,  │          0 │ add_10[0][0],     │
# │                     │ 64)               │            │ conv2d_30[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 128, 128,  │     36,928 │ add_11[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_31[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 128, 128,  │          0 │ add_11[0][0],     │
# │                     │ 64)               │            │ conv2d_32[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 128, 128,  │     36,928 │ add_12[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_34 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_33[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 128, 128,  │          0 │ add_12[0][0],     │
# │                     │ 64)               │            │ conv2d_34[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_35 (Conv2D)  │ (None, 128, 128,  │     36,928 │ add_13[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_36 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_35[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 128, 128,  │          0 │ add_13[0][0],     │
# │                     │ 64)               │            │ conv2d_36[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 128, 128,  │     36,928 │ add_14[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_38 (Conv2D)  │ (None, 128, 128,  │     36,928 │ conv2d_37[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 128, 128,  │          0 │ add_14[0][0],     │
# │                     │ 64)               │            │ conv2d_38[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_39 (Conv2D)  │ (None, 128, 128,  │      1,731 │ add_15[0][0]      │
# │                     │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,185,219 (4.52 MB)
#  Trainable params: 1,185,219 (4.52 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/300
# W0000 00:00:1759928378.041975     102 assert_op.cc:38] Ignoring Assert operator PSNR/Assert/Assert
# W0000 00:00:1759928378.042058     102 assert_op.cc:38] Ignoring Assert operator PSNR/Assert_1/Assert
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - loss: 1.4145 - psnr_metric: 5.8802
# W0000 00:00:1759928403.878168     103 assert_op.cc:38] Ignoring Assert operator PSNR/Assert/Assert
# W0000 00:00:1759928403.878251     103 assert_op.cc:38] Ignoring Assert operator PSNR/Assert_1/Assert
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step - loss: 1.4027 - psnr_metric: 5.9449
# Epoch 1: val_psnr_metric improved from -inf to 16.92240, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 47s 341ms/step - loss: 1.3911 - psnr_metric: 6.0081 - val_loss: 0.0241 - val_psnr_metric: 16.9224 - learning_rate: 1.0000e-04
# Epoch 2/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 0.0214 - psnr_metric: 17.5193
# Epoch 2: val_psnr_metric improved from 16.92240 to 19.29048, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0214 - psnr_metric: 17.5254 - val_loss: 0.0141 - val_psnr_metric: 19.2905 - learning_rate: 1.0000e-04
# Epoch 3/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - loss: 0.0132 - psnr_metric: 19.6411
# Epoch 3: val_psnr_metric improved from 19.29048 to 20.98482, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - loss: 0.0132 - psnr_metric: 19.6452 - val_loss: 0.0096 - val_psnr_metric: 20.9848 - learning_rate: 1.0000e-04
# Epoch 4/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0091 - psnr_metric: 21.2234
# Epoch 4: val_psnr_metric improved from 20.98482 to 22.19757, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0091 - psnr_metric: 21.2264 - val_loss: 0.0072 - val_psnr_metric: 22.1976 - learning_rate: 1.0000e-04
# Epoch 5/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - loss: 0.0069 - psnr_metric: 22.4164
# Epoch 5: val_psnr_metric improved from 22.19757 to 23.11262, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 258ms/step - loss: 0.0069 - psnr_metric: 22.4187 - val_loss: 0.0058 - val_psnr_metric: 23.1126 - learning_rate: 1.0000e-04
# Epoch 6/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0056 - psnr_metric: 23.3435
# Epoch 6: val_psnr_metric improved from 23.11262 to 23.66388, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0056 - psnr_metric: 23.3449 - val_loss: 0.0051 - val_psnr_metric: 23.6639 - learning_rate: 1.0000e-04
# Epoch 7/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.0048 - psnr_metric: 23.9711
# Epoch 7: val_psnr_metric improved from 23.66388 to 24.39476, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0048 - psnr_metric: 23.9727 - val_loss: 0.0043 - val_psnr_metric: 24.3948 - learning_rate: 1.0000e-04
# Epoch 8/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0043 - psnr_metric: 24.5214
# Epoch 8: val_psnr_metric improved from 24.39476 to 25.08731, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0043 - psnr_metric: 24.5227 - val_loss: 0.0037 - val_psnr_metric: 25.0873 - learning_rate: 1.0000e-04
# Epoch 9/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 0.0038 - psnr_metric: 25.0087
# Epoch 9: val_psnr_metric improved from 25.08731 to 25.53119, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 256ms/step - loss: 0.0038 - psnr_metric: 25.0095 - val_loss: 0.0034 - val_psnr_metric: 25.5312 - learning_rate: 1.0000e-04
# Epoch 10/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 0.0035 - psnr_metric: 25.4317
# Epoch 10: val_psnr_metric improved from 25.53119 to 25.84159, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 256ms/step - loss: 0.0035 - psnr_metric: 25.4320 - val_loss: 0.0031 - val_psnr_metric: 25.8416 - learning_rate: 1.0000e-04
# Epoch 11/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 0.0032 - psnr_metric: 25.8163
# Epoch 11: val_psnr_metric improved from 25.84159 to 26.16160, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 256ms/step - loss: 0.0032 - psnr_metric: 25.8162 - val_loss: 0.0029 - val_psnr_metric: 26.1616 - learning_rate: 1.0000e-04
# Epoch 12/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0030 - psnr_metric: 26.1376
# Epoch 12: val_psnr_metric improved from 26.16160 to 26.48923, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0030 - psnr_metric: 26.1376 - val_loss: 0.0027 - val_psnr_metric: 26.4892 - learning_rate: 1.0000e-04
# Epoch 13/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0029 - psnr_metric: 26.3330
# Epoch 13: val_psnr_metric improved from 26.48923 to 26.64456, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0029 - psnr_metric: 26.3319 - val_loss: 0.0026 - val_psnr_metric: 26.6446 - learning_rate: 1.0000e-04
# Epoch 14/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0027 - psnr_metric: 26.6926
# Epoch 14: val_psnr_metric improved from 26.64456 to 26.94923, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0027 - psnr_metric: 26.6922 - val_loss: 0.0025 - val_psnr_metric: 26.9492 - learning_rate: 1.0000e-04
# Epoch 15/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0026 - psnr_metric: 26.8127
# Epoch 15: val_psnr_metric improved from 26.94923 to 27.16510, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0026 - psnr_metric: 26.8121 - val_loss: 0.0023 - val_psnr_metric: 27.1651 - learning_rate: 1.0000e-04
# Epoch 16/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0024 - psnr_metric: 27.0656
# Epoch 16: val_psnr_metric did not improve from 27.16510
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - loss: 0.0024 - psnr_metric: 27.0643 - val_loss: 0.0024 - val_psnr_metric: 27.0778 - learning_rate: 1.0000e-04
# Epoch 17/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0025 - psnr_metric: 26.7882
# Epoch 17: val_psnr_metric improved from 27.16510 to 27.49794, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0025 - psnr_metric: 26.7890 - val_loss: 0.0022 - val_psnr_metric: 27.4979 - learning_rate: 1.0000e-04
# Epoch 18/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0023 - psnr_metric: 27.4075
# Epoch 18: val_psnr_metric improved from 27.49794 to 27.62865, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0023 - psnr_metric: 27.4065 - val_loss: 0.0021 - val_psnr_metric: 27.6287 - learning_rate: 1.0000e-04
# Epoch 19/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0022 - psnr_metric: 27.4661
# Epoch 19: val_psnr_metric improved from 27.62865 to 27.74991, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0022 - psnr_metric: 27.4653 - val_loss: 0.0021 - val_psnr_metric: 27.7499 - learning_rate: 1.0000e-04
# Epoch 20/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0022 - psnr_metric: 27.5265
# Epoch 20: val_psnr_metric did not improve from 27.74991
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 252ms/step - loss: 0.0022 - psnr_metric: 27.5250 - val_loss: 0.0021 - val_psnr_metric: 27.5982 - learning_rate: 1.0000e-04
# Epoch 21/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0023 - psnr_metric: 27.3018
# Epoch 21: val_psnr_metric improved from 27.74991 to 27.99831, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0023 - psnr_metric: 27.3027 - val_loss: 0.0020 - val_psnr_metric: 27.9983 - learning_rate: 1.0000e-04
# Epoch 22/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0020 - psnr_metric: 27.9068
# Epoch 22: val_psnr_metric improved from 27.99831 to 28.03680, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0020 - psnr_metric: 27.9055 - val_loss: 0.0019 - val_psnr_metric: 28.0368 - learning_rate: 1.0000e-04
# Epoch 23/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0021 - psnr_metric: 27.7602
# Epoch 23: val_psnr_metric improved from 28.03680 to 28.16542, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0021 - psnr_metric: 27.7599 - val_loss: 0.0019 - val_psnr_metric: 28.1654 - learning_rate: 1.0000e-04
# Epoch 24/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0020 - psnr_metric: 27.8805
# Epoch 24: val_psnr_metric did not improve from 28.16542
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 252ms/step - loss: 0.0020 - psnr_metric: 27.8790 - val_loss: 0.0019 - val_psnr_metric: 27.9470 - learning_rate: 1.0000e-04
# Epoch 25/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0021 - psnr_metric: 27.6787
# Epoch 25: val_psnr_metric improved from 28.16542 to 28.36766, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0021 - psnr_metric: 27.6798 - val_loss: 0.0018 - val_psnr_metric: 28.3677 - learning_rate: 1.0000e-04
# Epoch 26/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0019 - psnr_metric: 28.2005
# Epoch 26: val_psnr_metric did not improve from 28.36766
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0019 - psnr_metric: 28.1989 - val_loss: 0.0018 - val_psnr_metric: 28.3040 - learning_rate: 1.0000e-04
# Epoch 27/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0020 - psnr_metric: 27.8406
# Epoch 27: val_psnr_metric improved from 28.36766 to 28.52158, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0020 - psnr_metric: 27.8408 - val_loss: 0.0017 - val_psnr_metric: 28.5216 - learning_rate: 1.0000e-04
# Epoch 28/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0018 - psnr_metric: 28.3727
# Epoch 28: val_psnr_metric improved from 28.52158 to 28.59445, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0019 - psnr_metric: 28.3707 - val_loss: 0.0017 - val_psnr_metric: 28.5944 - learning_rate: 1.0000e-04
# Epoch 29/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0019 - psnr_metric: 28.0349
# Epoch 29: val_psnr_metric did not improve from 28.59445
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - loss: 0.0019 - psnr_metric: 28.0348 - val_loss: 0.0018 - val_psnr_metric: 28.3484 - learning_rate: 1.0000e-04
# Epoch 30/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0019 - psnr_metric: 28.2476
# Epoch 30: val_psnr_metric improved from 28.59445 to 28.73911, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0019 - psnr_metric: 28.2480 - val_loss: 0.0017 - val_psnr_metric: 28.7391 - learning_rate: 1.0000e-04
# Epoch 31/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0018 - psnr_metric: 28.4614
# Epoch 31: val_psnr_metric improved from 28.73911 to 28.77674, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0018 - psnr_metric: 28.4605 - val_loss: 0.0016 - val_psnr_metric: 28.7767 - learning_rate: 1.0000e-04
# Epoch 32/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.0018 - psnr_metric: 28.5608
# Epoch 32: val_psnr_metric did not improve from 28.77674
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - loss: 0.0018 - psnr_metric: 28.5589 - val_loss: 0.0017 - val_psnr_metric: 28.6092 - learning_rate: 1.0000e-04
# Epoch 33/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0019 - psnr_metric: 28.1529
# Epoch 33: val_psnr_metric improved from 28.77674 to 28.80966, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0019 - psnr_metric: 28.1533 - val_loss: 0.0016 - val_psnr_metric: 28.8097 - learning_rate: 1.0000e-04
# Epoch 34/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0018 - psnr_metric: 28.5276
# Epoch 34: val_psnr_metric did not improve from 28.80966
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - loss: 0.0018 - psnr_metric: 28.5263 - val_loss: 0.0017 - val_psnr_metric: 28.6692 - learning_rate: 1.0000e-04
# Epoch 35/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0018 - psnr_metric: 28.5551
# Epoch 35: val_psnr_metric did not improve from 28.80966
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - loss: 0.0018 - psnr_metric: 28.5535 - val_loss: 0.0017 - val_psnr_metric: 28.5972 - learning_rate: 1.0000e-04
# Epoch 36/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0018 - psnr_metric: 28.4395
# Epoch 36: val_psnr_metric improved from 28.80966 to 28.92386, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0018 - psnr_metric: 28.4387 - val_loss: 0.0016 - val_psnr_metric: 28.9239 - learning_rate: 1.0000e-04
# Epoch 37/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0017 - psnr_metric: 28.6110
# Epoch 37: val_psnr_metric improved from 28.92386 to 29.04640, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0017 - psnr_metric: 28.6111 - val_loss: 0.0016 - val_psnr_metric: 29.0464 - learning_rate: 1.0000e-04
# Epoch 38/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0017 - psnr_metric: 28.7742
# Epoch 38: val_psnr_metric improved from 29.04640 to 29.17028, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0017 - psnr_metric: 28.7734 - val_loss: 0.0015 - val_psnr_metric: 29.1703 - learning_rate: 1.0000e-04
# Epoch 39/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0016 - psnr_metric: 28.9103
# Epoch 39: val_psnr_metric improved from 29.17028 to 29.21398, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0016 - psnr_metric: 28.9095 - val_loss: 0.0015 - val_psnr_metric: 29.2140 - learning_rate: 1.0000e-04
# Epoch 40/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0017 - psnr_metric: 28.8498
# Epoch 40: val_psnr_metric did not improve from 29.21398
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 252ms/step - loss: 0.0017 - psnr_metric: 28.8458 - val_loss: 0.0015 - val_psnr_metric: 29.1710 - learning_rate: 1.0000e-04
# Epoch 41/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0016 - psnr_metric: 28.9811
# Epoch 41: val_psnr_metric improved from 29.21398 to 29.23651, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0016 - psnr_metric: 28.9800 - val_loss: 0.0015 - val_psnr_metric: 29.2365 - learning_rate: 1.0000e-04
# Epoch 42/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0016 - psnr_metric: 28.9571
# Epoch 42: val_psnr_metric did not improve from 29.23651
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 252ms/step - loss: 0.0016 - psnr_metric: 28.9512 - val_loss: 0.0033 - val_psnr_metric: 25.2365 - learning_rate: 1.0000e-04
# Epoch 43/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0021 - psnr_metric: 27.6352
# Epoch 43: val_psnr_metric improved from 29.23651 to 29.29908, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0021 - psnr_metric: 27.6430 - val_loss: 0.0015 - val_psnr_metric: 29.2991 - learning_rate: 1.0000e-04
# Epoch 44/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0016 - psnr_metric: 29.1786
# Epoch 44: val_psnr_metric improved from 29.29908 to 29.41024, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0016 - psnr_metric: 29.1776 - val_loss: 0.0014 - val_psnr_metric: 29.4102 - learning_rate: 1.0000e-04
# Epoch 45/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0016 - psnr_metric: 29.1321
# Epoch 45: val_psnr_metric did not improve from 29.41024
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 252ms/step - loss: 0.0016 - psnr_metric: 29.1308 - val_loss: 0.0015 - val_psnr_metric: 29.3391 - learning_rate: 1.0000e-04
# Epoch 46/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0016 - psnr_metric: 28.8442
# Epoch 46: val_psnr_metric did not improve from 29.41024
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 252ms/step - loss: 0.0016 - psnr_metric: 28.8427 - val_loss: 0.0015 - val_psnr_metric: 29.3494 - learning_rate: 1.0000e-04
# Epoch 47/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0017 - psnr_metric: 28.7504
# Epoch 47: val_psnr_metric improved from 29.41024 to 29.50694, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0017 - psnr_metric: 28.7512 - val_loss: 0.0014 - val_psnr_metric: 29.5069 - learning_rate: 1.0000e-04
# Epoch 48/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0015 - psnr_metric: 29.2930
# Epoch 48: val_psnr_metric improved from 29.50694 to 29.51252, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0015 - psnr_metric: 29.2917 - val_loss: 0.0014 - val_psnr_metric: 29.5125 - learning_rate: 1.0000e-04
# Epoch 49/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.0016 - psnr_metric: 29.1530
# Epoch 49: val_psnr_metric did not improve from 29.51252
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - loss: 0.0016 - psnr_metric: 29.1491 - val_loss: 0.0019 - val_psnr_metric: 27.9217 - learning_rate: 1.0000e-04
# Epoch 50/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0018 - psnr_metric: 28.5486
# Epoch 50: val_psnr_metric improved from 29.51252 to 29.59512, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0018 - psnr_metric: 28.5522 - val_loss: 0.0014 - val_psnr_metric: 29.5951 - learning_rate: 1.0000e-04
# Epoch 51/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0015 - psnr_metric: 29.3180
# Epoch 51: val_psnr_metric improved from 29.59512 to 29.64056, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0015 - psnr_metric: 29.3174 - val_loss: 0.0014 - val_psnr_metric: 29.6406 - learning_rate: 1.0000e-04
# Epoch 52/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.0015 - psnr_metric: 29.1517
# Epoch 52: val_psnr_metric did not improve from 29.64056
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - loss: 0.0015 - psnr_metric: 29.1502 - val_loss: 0.0014 - val_psnr_metric: 29.4398 - learning_rate: 1.0000e-04
# Epoch 53/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.0015 - psnr_metric: 29.4651
# Epoch 53: val_psnr_metric improved from 29.64056 to 29.70016, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0015 - psnr_metric: 29.4643 - val_loss: 0.0014 - val_psnr_metric: 29.7002 - learning_rate: 5.0000e-05
# Epoch 54/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.0015 - psnr_metric: 29.5428
# Epoch 54: val_psnr_metric improved from 29.70016 to 29.71939, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0015 - psnr_metric: 29.5416 - val_loss: 0.0014 - val_psnr_metric: 29.7194 - learning_rate: 5.0000e-05
# Epoch 55/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.0015 - psnr_metric: 29.5626
# Epoch 55: val_psnr_metric did not improve from 29.71939
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - loss: 0.0015 - psnr_metric: 29.5614 - val_loss: 0.0014 - val_psnr_metric: 29.7151 - learning_rate: 5.0000e-05
# Epoch 56/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.0014 - psnr_metric: 29.5813
# Epoch 56: val_psnr_metric improved from 29.71939 to 29.73015, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0014 - psnr_metric: 29.5801 - val_loss: 0.0013 - val_psnr_metric: 29.7301 - learning_rate: 5.0000e-05
# Epoch 57/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.5993
# Epoch 57: val_psnr_metric improved from 29.73015 to 29.76462, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0014 - psnr_metric: 29.5981 - val_loss: 0.0013 - val_psnr_metric: 29.7646 - learning_rate: 5.0000e-05
# Epoch 58/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.6144
# Epoch 58: val_psnr_metric improved from 29.76462 to 29.78768, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.6133 - val_loss: 0.0013 - val_psnr_metric: 29.7877 - learning_rate: 5.0000e-05
# Epoch 59/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.6238
# Epoch 59: val_psnr_metric improved from 29.78768 to 29.80387, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.6227 - val_loss: 0.0013 - val_psnr_metric: 29.8039 - learning_rate: 5.0000e-05
# Epoch 60/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.6135
# Epoch 60: val_psnr_metric improved from 29.80387 to 29.82641, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.6124 - val_loss: 0.0013 - val_psnr_metric: 29.8264 - learning_rate: 5.0000e-05
# Epoch 61/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0014 - psnr_metric: 29.6500
# Epoch 61: val_psnr_metric improved from 29.82641 to 29.82906, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0014 - psnr_metric: 29.6488 - val_loss: 0.0013 - val_psnr_metric: 29.8291 - learning_rate: 5.0000e-05
# Epoch 62/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.6087
# Epoch 62: val_psnr_metric did not improve from 29.82906
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - loss: 0.0014 - psnr_metric: 29.6072 - val_loss: 0.0013 - val_psnr_metric: 29.7843 - learning_rate: 5.0000e-05
# Epoch 63/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.0014 - psnr_metric: 29.5646
# Epoch 63: val_psnr_metric improved from 29.82906 to 29.85742, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0014 - psnr_metric: 29.5640 - val_loss: 0.0013 - val_psnr_metric: 29.8574 - learning_rate: 5.0000e-05
# Epoch 64/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.0015 - psnr_metric: 29.4865
# Epoch 64: val_psnr_metric did not improve from 29.85742
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - loss: 0.0015 - psnr_metric: 29.4853 - val_loss: 0.0013 - val_psnr_metric: 29.6971 - learning_rate: 5.0000e-05
# Epoch 65/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0015 - psnr_metric: 29.4418
# Epoch 65: val_psnr_metric improved from 29.85742 to 29.90112, saving model to /kaggle/working/edsr_best.h5
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0015 - psnr_metric: 29.4414 - val_loss: 0.0013 - val_psnr_metric: 29.9011 - learning_rate: 5.0000e-05
# Epoch 66/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.7424
# Epoch 66: val_psnr_metric improved from 29.90112 to 29.92208, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.7412 - val_loss: 0.0013 - val_psnr_metric: 29.9221 - learning_rate: 2.5000e-05
# Epoch 67/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0014 - psnr_metric: 29.7537
# Epoch 67: val_psnr_metric improved from 29.92208 to 29.93150, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.7525 - val_loss: 0.0013 - val_psnr_metric: 29.9315 - learning_rate: 2.5000e-05
# Epoch 68/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0014 - psnr_metric: 29.7637
# Epoch 68: val_psnr_metric improved from 29.93150 to 29.94031, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0014 - psnr_metric: 29.7625 - val_loss: 0.0013 - val_psnr_metric: 29.9403 - learning_rate: 2.5000e-05
# Epoch 69/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0014 - psnr_metric: 29.7725
# Epoch 69: val_psnr_metric did not improve from 29.94031
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 252ms/step - loss: 0.0014 - psnr_metric: 29.7713 - val_loss: 0.0013 - val_psnr_metric: 29.9400 - learning_rate: 2.5000e-05
# Epoch 70/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0014 - psnr_metric: 29.7805
# Epoch 70: val_psnr_metric improved from 29.94031 to 29.94597, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0014 - psnr_metric: 29.7793 - val_loss: 0.0013 - val_psnr_metric: 29.9460 - learning_rate: 2.5000e-05
# Epoch 71/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.7885
# Epoch 71: val_psnr_metric improved from 29.94597 to 29.95110, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.7873 - val_loss: 0.0013 - val_psnr_metric: 29.9511 - learning_rate: 2.5000e-05
# Epoch 72/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.7972
# Epoch 72: val_psnr_metric improved from 29.95110 to 29.96188, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.7960 - val_loss: 0.0013 - val_psnr_metric: 29.9619 - learning_rate: 2.5000e-05
# Epoch 73/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.8065
# Epoch 73: val_psnr_metric improved from 29.96188 to 29.97666, saving model to /kaggle/working/edsr_best.h5
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0014 - psnr_metric: 29.8053 - val_loss: 0.0013 - val_psnr_metric: 29.9767 - learning_rate: 2.5000e-05
# Epoch 74/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.0014 - psnr_metric: 29.8181
# Epoch 74: val_psnr_metric improved from 29.97666 to 29.99481, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0014 - psnr_metric: 29.8169 - val_loss: 0.0013 - val_psnr_metric: 29.9948 - learning_rate: 1.2500e-05
# Epoch 75/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.0014 - psnr_metric: 29.8260
# Epoch 75: val_psnr_metric improved from 29.99481 to 30.00032, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0014 - psnr_metric: 29.8248 - val_loss: 0.0013 - val_psnr_metric: 30.0003 - learning_rate: 1.2500e-05
# Epoch 76/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.0014 - psnr_metric: 29.8306
# Epoch 76: val_psnr_metric improved from 30.00032 to 30.00534, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0014 - psnr_metric: 29.8293 - val_loss: 0.0013 - val_psnr_metric: 30.0053 - learning_rate: 1.2500e-05
# Epoch 77/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.0014 - psnr_metric: 29.8351
# Epoch 77: val_psnr_metric improved from 30.00534 to 30.00904, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0014 - psnr_metric: 29.8339 - val_loss: 0.0013 - val_psnr_metric: 30.0090 - learning_rate: 1.2500e-05
# Epoch 78/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.8390
# Epoch 78: val_psnr_metric improved from 30.00904 to 30.01297, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0014 - psnr_metric: 29.8378 - val_loss: 0.0013 - val_psnr_metric: 30.0130 - learning_rate: 1.2500e-05
# Epoch 79/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.8426
# Epoch 79: val_psnr_metric improved from 30.01297 to 30.02035, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.8414 - val_loss: 0.0013 - val_psnr_metric: 30.0204 - learning_rate: 1.2500e-05
# Epoch 80/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.8485
# Epoch 80: val_psnr_metric improved from 30.02035 to 30.02700, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.8473 - val_loss: 0.0013 - val_psnr_metric: 30.0270 - learning_rate: 1.2500e-05
# Epoch 81/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.8553
# Epoch 81: val_psnr_metric improved from 30.02700 to 30.03245, saving model to /kaggle/working/edsr_best.h5
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.8540 - val_loss: 0.0013 - val_psnr_metric: 30.0324 - learning_rate: 1.2500e-05
# Epoch 82/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.8632
# Epoch 82: val_psnr_metric improved from 30.03245 to 30.03604, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.8620 - val_loss: 0.0013 - val_psnr_metric: 30.0360 - learning_rate: 6.2500e-06
# Epoch 83/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.8673
# Epoch 83: val_psnr_metric improved from 30.03604 to 30.03842, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.8661 - val_loss: 0.0013 - val_psnr_metric: 30.0384 - learning_rate: 6.2500e-06
# Epoch 84/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.8700
# Epoch 84: val_psnr_metric improved from 30.03842 to 30.04106, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.8688 - val_loss: 0.0013 - val_psnr_metric: 30.0411 - learning_rate: 6.2500e-06
# Epoch 85/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.8726
# Epoch 85: val_psnr_metric improved from 30.04106 to 30.04460, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0014 - psnr_metric: 29.8714 - val_loss: 0.0013 - val_psnr_metric: 30.0446 - learning_rate: 6.2500e-06
# Epoch 86/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.8754
# Epoch 86: val_psnr_metric improved from 30.04460 to 30.04829, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0014 - psnr_metric: 29.8741 - val_loss: 0.0013 - val_psnr_metric: 30.0483 - learning_rate: 6.2500e-06
# Epoch 87/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.8784
# Epoch 87: val_psnr_metric improved from 30.04829 to 30.05176, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.8772 - val_loss: 0.0013 - val_psnr_metric: 30.0518 - learning_rate: 6.2500e-06
# Epoch 88/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.8816
# Epoch 88: val_psnr_metric improved from 30.05176 to 30.05536, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.8804 - val_loss: 0.0013 - val_psnr_metric: 30.0554 - learning_rate: 6.2500e-06
# Epoch 89/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.8850
# Epoch 89: val_psnr_metric improved from 30.05536 to 30.05939, saving model to /kaggle/working/edsr_best.h5
#
# Epoch 89: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0014 - psnr_metric: 29.8838 - val_loss: 0.0013 - val_psnr_metric: 30.0594 - learning_rate: 6.2500e-06
# Epoch 90/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - loss: 0.0014 - psnr_metric: 29.8890
# Epoch 90: val_psnr_metric improved from 30.05939 to 30.06301, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0014 - psnr_metric: 29.8878 - val_loss: 0.0013 - val_psnr_metric: 30.0630 - learning_rate: 3.1250e-06
# Epoch 91/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.8914
# Epoch 91: val_psnr_metric improved from 30.06301 to 30.06485, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - loss: 0.0014 - psnr_metric: 29.8901 - val_loss: 0.0013 - val_psnr_metric: 30.0648 - learning_rate: 3.1250e-06
# Epoch 92/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.8931
# Epoch 92: val_psnr_metric improved from 30.06485 to 30.06673, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.8919 - val_loss: 0.0013 - val_psnr_metric: 30.0667 - learning_rate: 3.1250e-06
# Epoch 93/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0014 - psnr_metric: 29.8950
# Epoch 93: val_psnr_metric improved from 30.06673 to 30.06858, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0014 - psnr_metric: 29.8938 - val_loss: 0.0013 - val_psnr_metric: 30.0686 - learning_rate: 3.1250e-06
# Epoch 94/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.8970
# Epoch 94: val_psnr_metric improved from 30.06858 to 30.07052, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.8958 - val_loss: 0.0013 - val_psnr_metric: 30.0705 - learning_rate: 3.1250e-06
# Epoch 95/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.8990
# Epoch 95: val_psnr_metric improved from 30.07052 to 30.07262, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.8978 - val_loss: 0.0013 - val_psnr_metric: 30.0726 - learning_rate: 3.1250e-06
# Epoch 96/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.9010
# Epoch 96: val_psnr_metric improved from 30.07262 to 30.07470, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.8998 - val_loss: 0.0013 - val_psnr_metric: 30.0747 - learning_rate: 3.1250e-06
# Epoch 97/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.9031
# Epoch 97: val_psnr_metric improved from 30.07470 to 30.07664, saving model to /kaggle/working/edsr_best.h5
#
# Epoch 97: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.9018 - val_loss: 0.0013 - val_psnr_metric: 30.0766 - learning_rate: 3.1250e-06
# Epoch 98/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0014 - psnr_metric: 29.9056
# Epoch 98: val_psnr_metric improved from 30.07664 to 30.07835, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.9043 - val_loss: 0.0013 - val_psnr_metric: 30.0784 - learning_rate: 1.5625e-06
# Epoch 99/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0014 - psnr_metric: 29.9067
# Epoch 99: val_psnr_metric improved from 30.07835 to 30.07932, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0014 - psnr_metric: 29.9055 - val_loss: 0.0013 - val_psnr_metric: 30.0793 - learning_rate: 1.5625e-06
# Epoch 100/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0014 - psnr_metric: 29.9078
# Epoch 100: val_psnr_metric improved from 30.07932 to 30.08044, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 255ms/step - loss: 0.0014 - psnr_metric: 29.9066 - val_loss: 0.0013 - val_psnr_metric: 30.0804 - learning_rate: 1.5625e-06
# Epoch 101/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0014 - psnr_metric: 29.9089
# Epoch 101: val_psnr_metric improved from 30.08044 to 30.08170, saving model to /kaggle/working/edsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - loss: 0.0014 - psnr_metric: 29.9077 - val_loss: 0.0013 - val_psnr_metric: 30.0817 - learning_rate: 1.5625e-06
# Epoch 102/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0014 - psnr_metric: 29.9101
# ...
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.3871 - val_loss: 0.0012 - val_psnr_metric: 30.5231 - learning_rate: 1.0000e-06
# Epoch 257/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.3893
# Epoch 257: val_psnr_metric improved from 30.52308 to 30.52389, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.3879 - val_loss: 0.0012 - val_psnr_metric: 30.5239 - learning_rate: 1.0000e-06
# Epoch 258/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.3901
# Epoch 258: val_psnr_metric improved from 30.52389 to 30.52471, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.3887 - val_loss: 0.0012 - val_psnr_metric: 30.5247 - learning_rate: 1.0000e-06
# Epoch 259/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.3909
# Epoch 259: val_psnr_metric improved from 30.52471 to 30.52553, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.3896 - val_loss: 0.0012 - val_psnr_metric: 30.5255 - learning_rate: 1.0000e-06
# Epoch 260/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0012 - psnr_metric: 30.3917
# Epoch 260: val_psnr_metric improved from 30.52553 to 30.52635, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.3904 - val_loss: 0.0012 - val_psnr_metric: 30.5263 - learning_rate: 1.0000e-06
# Epoch 261/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0012 - psnr_metric: 30.3926
# Epoch 261: val_psnr_metric improved from 30.52635 to 30.52716, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.3912 - val_loss: 0.0012 - val_psnr_metric: 30.5272 - learning_rate: 1.0000e-06
# Epoch 262/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.3934
# Epoch 262: val_psnr_metric improved from 30.52716 to 30.52798, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.3920 - val_loss: 0.0012 - val_psnr_metric: 30.5280 - learning_rate: 1.0000e-06
# Epoch 263/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.3942
# Epoch 263: val_psnr_metric improved from 30.52798 to 30.52880, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.3928 - val_loss: 0.0012 - val_psnr_metric: 30.5288 - learning_rate: 1.0000e-06
# Epoch 264/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.3950
# Epoch 264: val_psnr_metric improved from 30.52880 to 30.52960, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.3936 - val_loss: 0.0012 - val_psnr_metric: 30.5296 - learning_rate: 1.0000e-06
# Epoch 265/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.3958
# Epoch 265: val_psnr_metric improved from 30.52960 to 30.53040, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.3945 - val_loss: 0.0012 - val_psnr_metric: 30.5304 - learning_rate: 1.0000e-06
# Epoch 266/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.3966
# Epoch 266: val_psnr_metric improved from 30.53040 to 30.53122, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.3953 - val_loss: 0.0012 - val_psnr_metric: 30.5312 - learning_rate: 1.0000e-06
# Epoch 267/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.3975
# Epoch 267: val_psnr_metric improved from 30.53122 to 30.53201, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.3961 - val_loss: 0.0012 - val_psnr_metric: 30.5320 - learning_rate: 1.0000e-06
# Epoch 268/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.3983
# Epoch 268: val_psnr_metric improved from 30.53201 to 30.53281, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.3969 - val_loss: 0.0012 - val_psnr_metric: 30.5328 - learning_rate: 1.0000e-06
# Epoch 269/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.3991
# Epoch 269: val_psnr_metric improved from 30.53281 to 30.53362, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.3977 - val_loss: 0.0012 - val_psnr_metric: 30.5336 - learning_rate: 1.0000e-06
# Epoch 270/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.3999
# Epoch 270: val_psnr_metric improved from 30.53362 to 30.53440, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - loss: 0.0012 - psnr_metric: 30.3985 - val_loss: 0.0012 - val_psnr_metric: 30.5344 - learning_rate: 1.0000e-06
# Epoch 271/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4007
# Epoch 271: val_psnr_metric improved from 30.53440 to 30.53520, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.3993 - val_loss: 0.0012 - val_psnr_metric: 30.5352 - learning_rate: 1.0000e-06
# Epoch 272/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4015
# Epoch 272: val_psnr_metric improved from 30.53520 to 30.53601, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4001 - val_loss: 0.0012 - val_psnr_metric: 30.5360 - learning_rate: 1.0000e-06
# Epoch 273/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4023
# Epoch 273: val_psnr_metric improved from 30.53601 to 30.53679, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4009 - val_loss: 0.0012 - val_psnr_metric: 30.5368 - learning_rate: 1.0000e-06
# Epoch 274/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4031
# Epoch 274: val_psnr_metric improved from 30.53679 to 30.53756, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4017 - val_loss: 0.0012 - val_psnr_metric: 30.5376 - learning_rate: 1.0000e-06
# Epoch 275/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4039
# Epoch 275: val_psnr_metric improved from 30.53756 to 30.53834, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4025 - val_loss: 0.0012 - val_psnr_metric: 30.5383 - learning_rate: 1.0000e-06
# Epoch 276/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4047
# Epoch 276: val_psnr_metric improved from 30.53834 to 30.53913, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4033 - val_loss: 0.0012 - val_psnr_metric: 30.5391 - learning_rate: 1.0000e-06
# Epoch 277/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0012 - psnr_metric: 30.4055
# Epoch 277: val_psnr_metric improved from 30.53913 to 30.53991, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4041 - val_loss: 0.0012 - val_psnr_metric: 30.5399 - learning_rate: 1.0000e-06
# Epoch 278/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4063
# Epoch 278: val_psnr_metric improved from 30.53991 to 30.54066, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4049 - val_loss: 0.0012 - val_psnr_metric: 30.5407 - learning_rate: 1.0000e-06
# Epoch 279/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4071
# Epoch 279: val_psnr_metric improved from 30.54066 to 30.54145, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4057 - val_loss: 0.0012 - val_psnr_metric: 30.5415 - learning_rate: 1.0000e-06
# Epoch 280/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4078
# Epoch 280: val_psnr_metric improved from 30.54145 to 30.54224, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4065 - val_loss: 0.0012 - val_psnr_metric: 30.5422 - learning_rate: 1.0000e-06
# Epoch 281/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4086
# Epoch 281: val_psnr_metric improved from 30.54224 to 30.54300, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - loss: 0.0012 - psnr_metric: 30.4073 - val_loss: 0.0012 - val_psnr_metric: 30.5430 - learning_rate: 1.0000e-06
# Epoch 282/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4094
# Epoch 282: val_psnr_metric improved from 30.54300 to 30.54377, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4081 - val_loss: 0.0012 - val_psnr_metric: 30.5438 - learning_rate: 1.0000e-06
# Epoch 283/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4102
# Epoch 283: val_psnr_metric improved from 30.54377 to 30.54454, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4088 - val_loss: 0.0012 - val_psnr_metric: 30.5445 - learning_rate: 1.0000e-06
# Epoch 284/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4110
# Epoch 284: val_psnr_metric improved from 30.54454 to 30.54532, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - loss: 0.0012 - psnr_metric: 30.4096 - val_loss: 0.0012 - val_psnr_metric: 30.5453 - learning_rate: 1.0000e-06
# Epoch 285/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4118
# Epoch 285: val_psnr_metric improved from 30.54532 to 30.54610, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - loss: 0.0012 - psnr_metric: 30.4104 - val_loss: 0.0012 - val_psnr_metric: 30.5461 - learning_rate: 1.0000e-06
# Epoch 286/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4125
# Epoch 286: val_psnr_metric improved from 30.54610 to 30.54686, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - loss: 0.0012 - psnr_metric: 30.4112 - val_loss: 0.0012 - val_psnr_metric: 30.5469 - learning_rate: 1.0000e-06
# Epoch 287/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4133
# Epoch 287: val_psnr_metric improved from 30.54686 to 30.54763, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4119 - val_loss: 0.0012 - val_psnr_metric: 30.5476 - learning_rate: 1.0000e-06
# Epoch 288/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4141
# Epoch 288: val_psnr_metric improved from 30.54763 to 30.54838, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - loss: 0.0012 - psnr_metric: 30.4127 - val_loss: 0.0012 - val_psnr_metric: 30.5484 - learning_rate: 1.0000e-06
# Epoch 289/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4149
# Epoch 289: val_psnr_metric improved from 30.54838 to 30.54914, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4135 - val_loss: 0.0012 - val_psnr_metric: 30.5491 - learning_rate: 1.0000e-06
# Epoch 290/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4156
# Epoch 290: val_psnr_metric improved from 30.54914 to 30.54990, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4143 - val_loss: 0.0012 - val_psnr_metric: 30.5499 - learning_rate: 1.0000e-06
# Epoch 291/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4164
# Epoch 291: val_psnr_metric improved from 30.54990 to 30.55064, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4150 - val_loss: 0.0012 - val_psnr_metric: 30.5506 - learning_rate: 1.0000e-06
# Epoch 292/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4172
# Epoch 292: val_psnr_metric improved from 30.55064 to 30.55141, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4158 - val_loss: 0.0012 - val_psnr_metric: 30.5514 - learning_rate: 1.0000e-06
# Epoch 293/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4179
# Epoch 293: val_psnr_metric improved from 30.55141 to 30.55216, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4166 - val_loss: 0.0012 - val_psnr_metric: 30.5522 - learning_rate: 1.0000e-06
# Epoch 294/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4187
# Epoch 294: val_psnr_metric improved from 30.55216 to 30.55292, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4173 - val_loss: 0.0012 - val_psnr_metric: 30.5529 - learning_rate: 1.0000e-06
# Epoch 295/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4195
# Epoch 295: val_psnr_metric improved from 30.55292 to 30.55367, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4181 - val_loss: 0.0012 - val_psnr_metric: 30.5537 - learning_rate: 1.0000e-06
# Epoch 296/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4203
# Epoch 296: val_psnr_metric improved from 30.55367 to 30.55443, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4189 - val_loss: 0.0012 - val_psnr_metric: 30.5544 - learning_rate: 1.0000e-06
# Epoch 297/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0012 - psnr_metric: 30.4210
# Epoch 297: val_psnr_metric improved from 30.55443 to 30.55517, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 148ms/step - loss: 0.0012 - psnr_metric: 30.4196 - val_loss: 0.0012 - val_psnr_metric: 30.5552 - learning_rate: 1.0000e-06
# Epoch 298/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0012 - psnr_metric: 30.4218
# Epoch 298: val_psnr_metric improved from 30.55517 to 30.55593, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - loss: 0.0012 - psnr_metric: 30.4204 - val_loss: 0.0012 - val_psnr_metric: 30.5559 - learning_rate: 1.0000e-06
# Epoch 299/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0012 - psnr_metric: 30.4225
# Epoch 299: val_psnr_metric improved from 30.55593 to 30.55666, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 148ms/step - loss: 0.0012 - psnr_metric: 30.4212 - val_loss: 0.0012 - val_psnr_metric: 30.5567 - learning_rate: 1.0000e-06
# Epoch 300/300
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0012 - psnr_metric: 30.4233
# Epoch 300: val_psnr_metric improved from 30.55666 to 30.55741, saving model to /kaggle/working/vdsr_best.h5
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 13s 148ms/step - loss: 0.0012 - psnr_metric: 30.4219 - val_loss: 0.0012 - val_psnr_metric: 30.5574 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 300.
# ✅ Saved VDSR -> best: /kaggle/working/vdsr_best.h5, final: /kaggle/working/vdsr_final.h5
#
# All models trained and saved.

# %%
# 🧩 Cell 9 — Zip ALL outputs (models + previews) into one bundle for download
ts = datetime.now().strftime("%Y%m%d-%H%M%S")
bundle_dir = os.path.join(OUTPUT_DIR, f"sr_all_models_bundle_{ts}")
os.makedirs(bundle_dir, exist_ok=True)

# Copy files
for rec in all_model_records:
    # models
    for p in [rec["best"], rec["final"]]:
        if p and os.path.isfile(p):
            shutil.copy2(p, bundle_dir)
    # previews
    if os.path.isdir(rec["preds_dir"]):
        shutil.copytree(rec["preds_dir"], os.path.join(bundle_dir, os.path.basename(rec["preds_dir"])))

# metadata
meta = {
    "models": all_model_records,
    "target_size": list(TARGET_SIZE),
    "downscale": DOWNSCALE,
    "random_crops": RANDOM_CROPS,
    "epochs": EPOCHS,
    "batch_size": BATCH_SIZE,
    "learning_rate": float(LR),
    "created_at": ts,
}
with open(os.path.join(bundle_dir, "run_meta.json"), "w") as f:
    json.dump(meta, f, indent=2)

zip_path = os.path.join(OUTPUT_DIR, f"sr_all_models_{ts}")
shutil.make_archive(zip_path, "zip", bundle_dir)

print("Zipped to:", zip_path + ".zip")
print("Bundle contents:")
for root, dirs, files in os.walk(bundle_dir):
    for name in files:
        print("-", os.path.relpath(os.path.join(root, name), bundle_dir))
